# %%
from typing import dataclass_transform
#s1=[start:end:stop]
s1="my name is chhavi"
s1[3:5]
s1[-5:-2]
s2="python"
s2[0:5]
s3="[PYTHON]"
s3[0:8]
s3[2:8]
s3[len(s3) - 1]
s3[8:+8]
#concatention
s1="data"
s2="science"
print(s1+s2)
#repition
print(s1*5)
#memberswhip
"a"in s1
#lenth
print(len(s1))
#string
name="chhavi"
salary="20k"
print(f"(my name is {name} and my salsry is {salary})")
# Out:
# datascience
# 4
# (my name is chhavi and my salsry is 20k)

# %%
print("\U0001F60B")
print("\U0001F61A")
# Out:
# 😋
# 😚

# %%
# use of if
Age=20
if Age>=18:
  print("you are eligible for vote")
# Out:
# you are eligible for vote
