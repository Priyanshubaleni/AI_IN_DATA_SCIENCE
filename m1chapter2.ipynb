# %%
#conditionl
if True:
  print("conditions true")
if False:
  print("condit6ion false")
# Out:
# conditions true

# %%
#comparision
user="admin"
if user=="admin":
   print("access")
# Out:
# access

# %%
#logical opreter
Age=int(input("enter your Age"))
salary=int(input("enter your salary"))
if Age >=21 and salary >=25000:
    print("able for vote")
# Out:
# enter your Age21
# enter your salary25000
# able for vote

# %%
a=10
b=20
if a!=b:
     print("will print")
# Out:
# will print

# %%
no=100
if no>120:
  print("eligible")
else:
    print("no is less than 120")
# Out:
# no is less than 120

# %%
age=20
has id=True
if Age>=18:
      if has id:
        print("eligible for vote")

        print("not eligible")
# Out:
#   File "/tmp/ipykernel_18876/584490353.py", line 2
#     has id=True
#         ^
# SyntaxError: invalid syntax

# %%
#alif
m1=100
m2=90
m3=80
m4=70
m5=60
sum=m1+m2+m3+m4+m5
Avg=sum/5
if Avg<=100 and Avg>90:
  print("grade A")
  if Avg<=90 and Avg>80:
    print("grade B")

# %%
Day=int

# %%
Day=int(input("enter the day"))
if Day==1:
  print("monday")
elif Day==2:
  print("tuesday")
elif Day==3:
  print("wednesda")
elif Day==4:
  print("thrusday")
elif Day==5:
  print("fri")
elif Day==6:
  print("sat")
elif Day==7:
  print("sun")

# %%
# wap to find the largest no
no1=int(input("enter the nn"))
no2=int(input("enter the nn"))
no3=int(input("enter the nn"))
if no1>no2 and no1>no3:
  print("no1 is greater")
  if no2>no3:
    print("no2 is greater")
  else:
    print("no3 is greater")
else:
  print("no3 is greater")
# Out:
# enter the nn689
# enter the nn698
# enter the nn46
# no3 is greater

# %%
#wap tof find the no 0,+,or
number=int(input("enter the no "))
if number==0:
  print("zero")
elif number>0:
  print("positive")
else:
  print("negative")
# Out:
# enter the no 56
# positive

# %%
#wap to
